# %% [markdown]
# This is a two-step challenge and those who complete both the steps will be consider for next round.
#
# You will have a Json file to prepare the dataset which can be downloaded from the link mentioned below.
#
# You need to do a few tasks over the dataset. Task are mentioned below:
# JSON parsing with nested columns in a dataframe
# Data transformation and aggregations
# Validations
# Insights
#
# DOWNLOAD THE JSON FILE FORM HERE LINK:
# https://drive.google.com/file/d/1_XyMO2udgEwso-oIKdTCxRgg4LWA11o3/view
#
# Use patientDetails and consultationData (medicines) keys from this JSON file.

# %%
import pandas as pd
import json
import numpy as np

data = pd.read_json('DataEngineeringQ2.json')

# %%
data
# Out:
#          _id appointmentId                                     patientDetails  \
# 0   T6hf3rb5     40d2-9c9f  {'_id': 'T6hb630b3', 'firstName': 'Css', 'last...
# 1   T65g3rb5      40dbtc9f  {'_id': 'T6h33b300', 'firstName': 'Lokesh', 'l...
# 2   T7g6Srb5      g3Wt5c9f  {'_id': 'TjhB4373', 'phrId': '63b5hvy614d5', '...
# 3   94bg8W8d      fb6-a535  {'_id': '6df4R5b', 'phrId': '644nig7y', 'first...
# 4   T6h8H56c       67h7KL9  {'_id': 'lK9hy06a', 'firstName': 'Raghu Viju',...
# 5    T9Jh8c8        Hy7Y91  {'_id': 'kI9d5c6', 'firstName': 'Dinesh Kumar'...
# 6   9Is624b9     10dY8a-4a  {'_id': 'i9R324b7', 'phrId': '67Yt2b97', 'firs...
# 7   T8H9c3c6      e8056Ye8  {'_id': 'T6h41b5ad3d8002ad9c3c4', 'firstName':...
# 8    T8Ud380     dbc0-c66b  {'_id': 'T9Iy347e', 'firstName': 'Dinesh', 'la...
# 9    T345fG4        1576a7  {'_id': 'T4Rb1a2', 'firstName': 'Sanjay', 'las...
# 10  T4F6a175       b6Te4ac  {'_id': 'Tr4T2173', 'phrId': '6E48U79', 'first...
# ...

# %%
data['patientDetails']
# Out:
# 0     {'_id': 'T6hb630b3', 'firstName': 'Css', 'last...
# 1     {'_id': 'T6h33b300', 'firstName': 'Lokesh', 'l...
# 2     {'_id': 'TjhB4373', 'phrId': '63b5hvy614d5', '...
# 3     {'_id': '6df4R5b', 'phrId': '644nig7y', 'first...
# 4     {'_id': 'lK9hy06a', 'firstName': 'Raghu Viju',...
# 5     {'_id': 'kI9d5c6', 'firstName': 'Dinesh Kumar'...
# 6     {'_id': 'i9R324b7', 'phrId': '67Yt2b97', 'firs...
# 7     {'_id': 'T6h41b5ad3d8002ad9c3c4', 'firstName':...
# 8     {'_id': 'T9Iy347e', 'firstName': 'Dinesh', 'la...
# 9     {'_id': 'T4Rb1a2', 'firstName': 'Sanjay', 'las...
# 10    {'_id': 'Tr4T2173', 'phrId': '6E48U79', 'first...
# 11    {'_id': 'T6Wa50', 'firstName': 'Nirmala', 'las...
# 12    {'_id': '65sRa36', 'firstName': 'Satish', 'las...
# 13    {'_id': 'UG67231', 'phrId': 'T6a7231', 'firstN...
# 14    {'_id': 'E4u5Ea2', 'firstName': 'Satyanaaryan'...
# 15    {'_id': 'T4E7Ge6', 'firstName': 'Nivitha', 'la...
# 16    {'_id': '04Re22d', 'firstName': 'Tejpal', 'las...
# ...

# %%
data_ = pd.json_normalize(data['patientDetails'])

# %%
data_2 = pd.json_normalize(data['consultationData'])

# %%
data_
# Out:
#                        _id                 firstName     lastName emailId  \
# 0                T6hb630b3                       Css
# 1                T6h33b300                    Lokesh
# 2                 TjhB4373                     Shila          Das
# 3                  6df4R5b                   Bhavika  Ben Panchal
# 4                 lK9hy06a                Raghu Viju
# 5                  kI9d5c6              Dinesh Kumar
# 6                 i9R324b7                     Lalit     Sankhwal
# 7   T6h41b5ad3d8002ad9c3c4                      Ravi
# 8                 T9Iy347e                    Dinesh
# 9                  T4Rb1a2                    Sanjay
# 10                Tr4T2173                    Akshay       Akshay
# 11                  T6Wa50                   Nirmala
# 12                 65sRa36                    Satish
# 13                 UG67231                Kalaiarasi   Kalaiarasi
# 14                 E4u5Ea2              Satyanaaryan
# ...

# %%
data_2.head()
# Out:
#   adviceTemplates advices attachments chiefComplaints customOne customThree  \
# 0              []      []          []              []        []          []
# 1              []      []          []              []        []          []
# 2              []      []          []              []        []          []
# 3              []      []          []              []        []          []
# 4              []      []          []              []        []          []
#
#   customTwo disease doctorNotes emergencyInstructions  ... labTest  \
# 0        []      []                                []  ...      []
# 1        []      []                                []  ...      []
# 2        []      []                                []  ...      []
# 3        []      []                                []  ...      []
# 4        []      []                                []  ...      []
#
#   languageCode medicineTemplates  \
# 0           en                []
# 1           en                []
# ...

# %%
data_.describe()
# Out:
#             _id firstName lastName emailId gender alternateContact  \
# count        31        31       31      30     22                9
# unique       30        30        9       1      3                2
# top     Pdh97S6       Jay                       M
# freq          2         2       22      30     11                8
#
#                        birthDate    phrId      customId  chat._id  \
# count                         21        8            16        16
# unique                        18        7            16        16
# top     1996-05-16T18:30:00.000Z  Jus0480  3FPEUCW8HACJ  09hUb5c7
# freq                           2        2             1         1
#
#        chat.channelId
# count               1
# unique              1
# top          9IrR9ce7
# freq                1

# %%
data_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               31 non-null     object
#  1   firstName         31 non-null     object
#  2   lastName          31 non-null     object
#  3   emailId           30 non-null     object
#  4   gender            22 non-null     object
#  5   alternateContact  9 non-null      object
#  6   birthDate         21 non-null     object
#  7   phrId             8 non-null      object
#  8   customId          16 non-null     object
#  9   chat._id          16 non-null     object
#  10  chat.channelId    1 non-null      object
# dtypes: object(11)
# memory usage: 2.8+ KB

# %% [markdown]
# ## 1
# Share percentage of missing values, for the columns firstName, lastName and DOB from patientDetails.
#
# Note: Missing values are defined as blank and empty strings. Percentage rounded off to 2 decimal

# %%
## 1
## Share percentage of missing values, for the columns firstName, lastName and DOB from patientDetails.

## Note: Missing values are defined as blank and empty strings. Percentage rounded off to 2 decimal

# %%
# Replace blank and empty strings with NaN
data_ = data_.replace(r'^\s*$', np.nan, regex=True)

# %%
data_.head()
# Out:
#          _id   firstName     lastName  emailId gender alternateContact  \
# 0  T6hb630b3         Css          NaN      NaN    NaN              NaN
# 1  T6h33b300      Lokesh          NaN      NaN      M              NaN
# 2   TjhB4373       Shila          Das      NaN    NaN              NaN
# 3    6df4R5b     Bhavika  Ben Panchal      NaN      F              NaN
# 4   lK9hy06a  Raghu Viju          NaN      NaN    NaN              NaN
#
#                   birthDate         phrId customId chat._id chat.channelId
# 0                      None           NaN      NaN      NaN            NaN
# 1  1996-05-16T18:30:00.000Z           NaN      NaN      NaN            NaN
# 2                       NaN  63b5hvy614d5      NaN      NaN            NaN
# 3  1988-04-24T14:30:00.000Z      644nig7y      NaN      NaN            NaN
# 4                       NaN           NaN      NaN      NaN            NaN

# %%
total_nums = len(data_['_id'])
total_nums
# Out:
# 31

# %%
firstName_null = data_['firstName'].isnull().sum()

# %%
#  percentage
firstName_null/total_nums *100
# Out:
# 0.0

# %%
lastName_null = data_['lastName'].isnull().sum()

# %%
#  percentage
lastName_null/total_nums *100
# Out:
# 70.96774193548387

# %%
birthDate_null = data_['birthDate'].isnull().sum()

# %%
#  percentage
birthDate_null/total_nums *100
# Out:
# 32.25806451612903

# %% [markdown]
# What is the percentage of female gender after imputation of gender column basis mode.
# (1 Point)

# %%
data_['gender'].head()
# Out:
# 0     NaN
# 1       M
# 2     NaN
# 3       F
# 4     NaN
# 5       M
# 6       M
# 7     NaN
# 8       M
# 9       M
# 10      M
# 11      F
# 12    NaN
# 13      F
# 14    NaN
# 15      F
# 16      M
# 17      F
# 18      F
# 19    NaN
# 20      F
# 21      M
# 22      F
# 23    NaN
# 24      M
# 25    NaN
# 26    NaN
# 27      F
# 28      F
# 29      M
# 30      M
# Name: gender, dtype: object

# %%
data_['gender'].mode()
# Out:
# 0    M
# Name: gender, dtype: object

# %%
Counter(data_['gender'])
# Out:
# Counter({nan: 10, 'M': 11, 'F': 10})

# %% [markdown]
# What is the percentage of female gender after imputation of gender column basis mode.
# (1 Point)

# %%
10 / 21
# Out:
# 0.47619047619047616

# %% [markdown]
# Add a column ageGroup that categorizes patients into age groups (e.g., Child for ages 0-12, Teen for ages 13-19, Adult for ages 20-59, Senior for ages 60+).
#
# What is count of Adult?

# %%
data_['birthDate'].dtype()
# Out:
# 0                         None
# 1     1996-05-16T18:30:00.000Z
# 2                          NaN
# 3     1988-04-24T14:30:00.000Z
# 4                          NaN
# 5     1983-05-16T18:30:00.000Z
# 6     2003-06-27T14:30:00.000Z
# 7                          NaN
# 8     1983-05-16T18:30:00.000Z
# 9     1998-05-16T18:30:00.000Z
# 10    1988-04-08T00:00:00.000Z
# 11    1971-05-16T18:30:00.000Z
# 12    1970-05-16T18:30:00.000Z
# 13    1997-07-31T00:00:00.000Z
# 14                         NaN
# 15    1997-05-16T18:30:00.000Z
# 16    1972-05-16T18:30:00.000Z
# 17    2001-05-16T18:30:00.000Z
# 18                         NaN
# 19                         NaN
# 20    2001-08-27T00:00:00.000Z
# 21    1998-11-19T23:30:00.000Z
# 22    1996-05-16T18:30:00.000Z
# 23                         NaN
# 24    1992-05-16T18:30:00.000Z
# 25                         NaN
# 26                         NaN
# 27    1999-05-16T18:30:00.000Z
# 28    1972-05-16T18:30:00.000Z
# 29    1980-03-22T18:30:00.000Z
# ...

# %%
pd.to_datetime('today')
# Out:
# Timestamp('2024-07-19 05:17:16.355260')

# %%
data_date = data_.dropna(subset=['birthDate'])

# %%
data_date['birthDate'] = pd.to_datetime(data_date['birthDate'])
data_date['birthDate']

data_date['age'] = (pd.to_datetime('today') - data_date['birthDate'])

data_date['ageGroup'] = pd.cut(data_date['age'], bins=[0, 12, 19, 59, 120], labels=['Child', 'Teen', 'Adult', 'Senior'])
# Out:
# <ipython-input-93-d56051592cf2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_date['birthDate'] = pd.to_datetime(data_date['birthDate'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/datetimelike.py in _sub_datetimelike(self, other)
#    1119         try:
# -> 1120             self._assert_tzawareness_compat(other)
#    1121         except TypeError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/datetimes.py in _assert_tzawareness_compat(self, other)
#     747         elif other_tz is None:
# --> 748             raise TypeError(
# ...

# %%
  # Add a column ageGroup that categorizes patients into age groups (e.g., Child for ages 0-12, Teen for ages 13-19, Adult for ages 20-59, Senior for ages 60+).

# What is count of Adult?

# %%
# Calculate the average number of medicines prescribed in the dataset.

data_2['medicines'].head()
# Out:
# 0    [{'medicineId': '619404', 'medicineName': 'A',...
# 1    [{'medicineId': '619404', 'medicineName': 'A',...
# 2    [{'medicineId': '619404', 'medicineName': 'B',...
# 3    [{'medicineId': '619704', 'medicineName': 'B',...
# 4    [{'medicineId': '619384', 'medicineName': 'D',...
# Name: medicines, dtype: object

# %%
f  = lambda x : len(x)

# %%
data_try = data_2.copy()

# %%
data_try["medicines"].apply(f)
# Out:
# 0     2
# 1     2
# 2     3
# 3     1
# 4     2
# 5     4
# 6     2
# 7     1
# 8     1
# 9     0
# 10    1
# 11    3
# 12    0
# 13    3
# 14    0
# 15    3
# 16    2
# 17    3
# 18    4
# 19    0
# 20    1
# 21    3
# 22    4
# 23    3
# 24    0
# 25    4
# 26    2
# 27    4
# 28    0
# 29    4
# 30    4
# Name: medicines, dtype: int64

# %%
sum(data_try["medicines"].apply(f)) / 30
# Out:
# 2.2

# %%
data_try["medicines"]
# Out:
# 0     [{'medicineId': '619404', 'medicineName': 'A',...
# 1     [{'medicineId': '619404', 'medicineName': 'A',...
# 2     [{'medicineId': '619404', 'medicineName': 'B',...
# 3     [{'medicineId': '619704', 'medicineName': 'B',...
# 4     [{'medicineId': '619384', 'medicineName': 'D',...
# 5     [{'medicineId': '643404', 'medicineName': 'A',...
# 6     [{'medicineId': '632304', 'medicineName': 'D',...
# 7     [{'medicineId': '619404', 'medicineName': 'A',...
# 8     [{'medicineId': '619504', 'medicineName': 'E',...
# 9                                                    []
# 10    [{'medicineId': '619504', 'medicineName': 'E',...
# 11    [{'medicineId': '619504', 'medicineName': 'E',...
# 12                                                   []
# 13    [{'medicineId': '619504', 'medicineName': 'A',...
# 14                                                   []
# 15    [{'medicineId': '619504', 'medicineName': 'B',...
# 16    [{'medicineId': '619504', 'medicineName': 'C',...
# ...

# %%
data_try["medicines"][0]
# Out:
# [{'medicineId': '619404',
#   'medicineName': 'A',
#   'medicineNameStrengthType': '',
#   'frequency': '1-0-1',
#   'duration': '90',
#   'durationIn': 'DAYS',
#   'instruction': 'AFTER MEAL',
#   'isActive': True},
#  {'medicineId': '619804',
#   'medicineName': 'B',
#   'medicineNameStrengthType': '',
#   'frequency': '1-0-1',
#   'duration': '90',
#   'durationIn': 'DAYS',
#   'instruction': 'AFTER MEAL',
#   'isActive': False}]

# %%
data_try["medicines"][0][0]["medicineName"]
# Out:
# 'A'

# %%
meds = []
for i in data_try["medicines"] :
  for j in i:
    med = j["medicineName"]
    meds.append(med)

# %%
meds
# Out:
# ['A',
#  'B',
#  'A',
#  'C',
#  'B',
#  'A',
#  'C',
#  'B',
#  'D',
#  'A',
#  'A',
#  'D',
#  'E',
#  'C',
#  'D',
#  'E',
#  'A',
#  'E',
#  'E',
#  'E',
#  'A',
#  'D',
#  'A',
#  'B',
#  'D',
#  'B',
#  'D',
#  'C',
#  'C',
#  'A',
#  'A',
#  'C',
#  'B',
#  'A',
#  'B',
#  'C',
#  'D',
#  'D',
#  'D',
#  'D',
#  'B',
#  'A',
#  'G',
#  'B',
#  'D',
#  'A',
#  'B',
#  'C',
#  'D',
#  'A',
#  'E',
#  'C',
#  'C',
#  'D',
#  'A',
#  'C',
#  'C',
#  'D',
#  'A',
#  'B',
#  'C',
#  'D',
#  'A',
#  'D',
#  'D',
#  'B']

# %%
from  collections import Counter
Counter(meds)
# Out:
# Counter({'A': 17, 'B': 12, 'C': 13, 'D': 17, 'E': 6, 'G': 1})

# %%
l = Counter(meds)

# %%
sorted(l)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'G']

# %%
meds_a = []
for i in data_try["medicines"] :
  for j in i:
    med = j["isActive"]
    meds_a.append(med)

# %%
meds_a
# Out:
# [True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True]

# %%
l_a = Counter(meds)

# %%
a = dict(l_a)
a
# Out:
# {True: 46, False: 20}

# %%
# percentages
active = a[True]
non_active = a[False]
active , non_active
# Out:
# (46, 20)

# %%
active / (active + non_active) , non_active / (active + non_active)
# Out:
# (0.696969696969697, 0.30303030303030304)

# %%
# Add a column isValidMobile of boolean which contains the values true or false against each value from phoneNumber column If a phone number is a valid Indian phone number.

# CREATE YOUR OWN LOGIC, DON’T USE ANY EXTERNAL PYTHON LIBRARY FOR VALIDATION
#
# true : indicates number is valid
# false : indicates number is not valid

# Problem Statement: Design a logic to check whether a phone number is valid or not.

# General rules to check:
# A valid number can have '+91' or '91' as prefix, a valid number must lie be between 6000000000-9999999999

# Example:
# +919876787687 is valid
# 919877475896 is valid
# +913454768688 is invalid
# 9876787687 is valid
# 3454768688 is invalid
# 57769666 is invalid

# Return the number of valid phone numbers found in the dataset.

# %%
import pandas as pd

def validate_phone(phone):
    return ('91' in phone and 6000000000 <= int(phone[2:]) <= 9999999999) or ('+91' in phone and 6000000000 <= int(phone[2:]) <= 9999999999)

data['isValidMobile'] = data['phoneNumber'].apply(validate_phone)

# %%
data['phoneNumber']
# Out:
# 0        96686896670
# 1         9496368916
# 2         7787204833
# 3         9376756879
# 4         5267384241
# 5      +919826374025
# 6         7587265252
# 7         5586958767
# 8         9987602525
# 9         9234354366
# 10        4863281056
# 11        8687986800
# 12
# 13        7152684236
# 14
# 15        9184723620
# 16
# 17        5847346075
# 18        9064537237
# 19
# 20         992727892
# 21        6888324121
# 22        8248594521
# 23     +917938475936
# 24    +9124648979746
# 25     +916883788633
# 26     +916636278363
# 27        6525356535
# 28
# 29     +919093872282
# 30     +916888324121
# Name: phoneNumber, dtype: object

# %%
data['isValidMobile']
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# Name: isValidMobile, dtype: bool

# %%
import pandas as pd

correlation = data_try["medicines"].apply(f).corr(date['age'])
rounded_correlation = round(correlation, 2)

print(rounded_correlation)
